# %%
from deepface import DeepFace
from deepface.detectors import FaceDetector
import dlib
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("emotion_example.png")
plt.imshow(img)
plt.show()

result = DeepFace.analyze(img, actions = ['emotion'], enforce_detection =  False)
print(result)
print(result['dominant_emotion'])
# Out:
# {'emotion': {'angry': 4.905137060418063e-10, 'disgust': 4.050871013377055e-14, 'fear': 4.962135910502319e-09, 'happy': 99.99990463256836, 'sad': 8.129738549023102e-09, 'surprise': 7.495357112752288e-08, 'neutral': 9.284223096983624e-05}, 'dominant_emotion': 'happy', 'region': {'x': 101, 'y': 55, 'w': 74, 'h': 74}}
# happy

# %%
img = cv2.imread("test.jpg")
dets = detector.run(img, 1)
for i, d in enumerate(dets):
    print("Detection {}, score: {}, face_type:{}".format(
         d, scores[i], idx[i]))
    crop = img[d.top():d.bottom(), d.left():d.right()]
    cv2.imwrite("cropped.jpg", crop)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 img = cv2.imread("test.jpg")
# ----> 2 dets = detector.run(img, 1)
#       3 for i, d in enumerate(dets):
#       4     print("Detection {}, score: {}, face_type:{}".format(
#       5          d, scores[i], idx[i]))
#
# AttributeError: 'Function' object has no attribute 'run'
